# %% [markdown]
# Prerequisites and Notes
#
# Installation: The error likely stems from an incomplete/outdated timesfm package. Install from source (editable mode) as per the repo:
#
# ```bash
# git clone https://github.com/google-research/timesfm.git
# cd timesfm
# pip install -e .
# ```

# %%
# Cell 2: Imports
# Ensure all available; from finetuning_torch.py and notebook
import os
from typing import Tuple

import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset
import yfinance as yf  # For external data augmentation if needed
import wandb  # Optional for logging

from timesfm import TimesFmCheckpoint, TimesFmHparams
from timesfm.timesfm_torch import TimesFmTorch
from timesfm.pytorch_patched_decoder import PatchedTimeSeriesDecoder, create_quantiles

# From finetuning_torch.py (assume in path or copy classes here if modularizing later)
from finetuning.finetuning_torch import (
    MetricsLogger, WandBLogger, DistributedManager,
    FinetuningConfig, TimesFMFinetuner
)

# Project-specific (adapt paths; from your src/)
from dataprep import dataprep  # Your data prep class
from configs import TrainConfig  # If needed for params

print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
#  See https://github.com/google-research/timesfm/blob/master/README.md for updated APIs.
# Loaded PyTorch TimesFM, likely because python version is 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:48:23) [GCC 13.3.0].
# CUDA available: True
# /root/anaconda3/envs/mitsui/lib/python3.11/site-packages/gluonts/json.py:102: UserWarning: Using `json`-module for json-handling. Consider installing one of `orjson`, `ujson` to speed up serialization and deserialization.
#   warnings.warn(

# %%
# Cell 3: Data Preparation - Load and Preprocess Project Data
# Use dataprep.py to load; melt targets for univariate/multi-target handling
# Augment with relevant prices (yfinance for LME/CME-like; offline in competition)

# Initialize data preparer (from your dataprep.py)
data_path = '../data'  # Update to your train.csv, train_labels.csv
data_preparer = dataprep(data_path)
data_preparer.one_shot_prep()

# Targets: 424 series from train_labels.csv
Y_full = data_preparer.Y_full_np  # (N~600, T=424)
#dates = data_preparer.dates  # Or derive from date_id

# For univariate: Treat each target column as separate series
# Shape: List of 424 arrays, each (N,)
univariate_series = [Y_full[:, i] for i in range(424)]

# For multivariate: Incorporate features from train.csv (X_full_np: N, F~558)
# Scalarize per target: e.g., mean of all features + target history (univariate proxy)
X_full = data_preparer.X_full_np  # (N, F)
multivariate_series = []
for i in range(424):
    target_hist = Y_full[:, i]
    feat_mean = np.nanmean(X_full, axis=1)  # Or PCA/project: simplify to mean for demo
    combined = np.vstack([target_hist, feat_mean]).T  # (N, 2); project to univariate if needed
    combined_scalar = np.mean(combined, axis=1)  # Scalarize to univariate (N,)
    multivariate_series.append(combined_scalar)

# Choose mode: univariate or multivariate
use_multivariate = False  # Toggle True for multivariate
series_list = multivariate_series if use_multivariate else univariate_series

print(f"Prepared {len(series_list)} series; each shape: {series_list[0].shape}")
# Out:
# 2025-10-02 15:28:16,175 - INFO - Loading train.csv from ../data/train.csv
# 2025-10-02 15:28:16,277 - INFO - Loading train_labels.csv from ../data/train_labels.csv
# 2025-10-02 15:28:16,399 - INFO - Loading target_pairs.csv from ../data/target_pairs.csv
# 2025-10-02 15:28:16,552 - INFO - X_full NaNs after imputation: 0
# 2025-10-02 15:28:16,553 - INFO - Y_full NaNs before imputation: 0
# 2025-10-02 15:28:16,555 - INFO - Y_full NaNs after imputation: 0
# 2025-10-02 15:28:16,555 - INFO - X_full feature count: 1671
# 2025-10-02 15:28:16,564 - INFO - Data loaded: X_full_np shape=(1917, 1671), Y_full_np shape=(1917, 424)
# Prepared 424 series; each shape: (1917,)

# %%
# Cell 4: Create TimeSeriesDataset for Fine-Tuning
# Ensures horizon_length=1 for single-step prediction

import torch
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    """Dataset for time series data compatible with TimesFM."""
    def __init__(self, series: np.ndarray, context_length: int, horizon_length: int = 1, freq_type: int = 0):
        if freq_type not in [0, 1, 2]:
            raise ValueError("freq_type must be 0, 1, or 2")
        self.series = np.asarray(series, dtype=np.float32)
        self.context_length = context_length
        self.horizon_length = horizon_length
        self.freq_type = freq_type
        self._prepare_samples()

    def _prepare_samples(self) -> None:
        self.samples = []
        total_length = self.context_length + self.horizon_length
        for start_idx in range(0, len(self.series) - total_length + 1):
            end_idx = start_idx + self.context_length
            x_context = self.series[start_idx:end_idx]
            x_future = self.series[end_idx:end_idx + self.horizon_length]  # (horizon_length=1,)
            if np.all(np.isfinite(x_context)) and np.all(np.isfinite(x_future)):
                self.samples.append((x_context, x_future))
            else:
                print(f"Skipping invalid sample at {start_idx}")

    def __len__(self) -> int:
        return len(self.samples)

    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
        x_context, x_future = self.samples[index]
        x_context = torch.tensor(x_context, dtype=torch.float32)  # (context_length,)
        x_future = torch.tensor(x_future, dtype=torch.float32)  # (horizon_length=1,)
        if x_future.dim() == 1:
            x_future = x_future.unsqueeze(-1)  # (horizon_length=1, 1)
        input_padding = torch.zeros_like(x_context)  # (context_length,)
        freq = torch.tensor([self.freq_type], dtype=torch.long)  # (1,)
        #print(f"Sample {index}: x_future shape {x_future.shape}")
        return x_context, input_padding, freq, x_future

# Params: Match competition (horizon=1, context~480)
context_length = 512  # Up to 8192; use 512 for efficiency
horizon_length = 1    # One-step-ahead
freq_type = 0         # Daily/unknown
train_split = 0.8     # ~480 train, ~120 val per series

datasets = []
for series in series_list:
    train_size = int(len(series) * train_split)
    train_data = series[:train_size]
    val_data = series[train_size:]
    train_dataset = TimeSeriesDataset(train_data, context_length, horizon_length, freq_type)
    val_dataset = TimeSeriesDataset(val_data, context_length, horizon_length, freq_type)
    datasets.append((train_dataset, val_dataset))

print(f"Created {len(datasets)} datasets; sample train len: {len(datasets[0][0])}, val len: {len(datasets[0][1])}")
# Out:
# Created 424 datasets; sample train len: 1021, val len: 0

# %%
# Cell 5: Initialize Model and Fine-Tuner
# Load TimesFM v1.0-200m (foundational v1); fine-tune with FinetuningConfig/TimesFMFinetuner

import timesfm
from timesfm import TimesFmHparams, TimesFmCheckpoint
from timesfm.pytorch_patched_decoder import PatchedTimeSeriesDecoder, create_quantiles
import torch


# Define model hyperparameters
hparams = TimesFmHparams(
    num_layers=20,
    num_heads=16,
    model_dims=1280,
    input_patch_len=32,
    output_patch_len=128,
    quantiles=create_quantiles(),
    use_positional_embedding=True,
    horizon_len=1  # Explicitly set for univariate single-target forecasting
)

# Define checkpoint
checkpoint = TimesFmCheckpoint(
    path = '/root/vscode/portfolio/mitsui_2025/checkpoints/timesfm-1.0-200m/torch_model.ckpt'
)

# Initialize TimesFM model
tfm = TimesFmTorch(
    hparams=hparams,
    checkpoint=checkpoint,
)

# Load pretrained checkpoint
tfm.load_from_checkpoint(checkpoint)

# Fine-tuning config
config = FinetuningConfig(
    batch_size=32,
    num_epochs=50,
    learning_rate=1e-4,
    weight_decay=0.01,
    freq_type=0,
    use_quantile_loss=True,
    quantiles=create_quantiles(),
    device="cpu",
    distributed=False,
    use_wandb=False,
    log_every_n_steps=10,
    val_check_interval=0.5
)

# Initialize finetuner
finetuners = []
for i, (train_ds, val_ds) in enumerate(datasets):
    finetuner = TimesFMFinetuner(
        model=tfm._model,
        config=config,
        rank=0,
        loss_fn=None
    )
    finetuners.append(finetuner)
    print(f"Initialized finetuner for target {i}")


print("Model and finetuners initialized.")
# Out:
# 2025-10-02 15:28:22,196 - INFO - Loading checkpoint from /root/vscode/portfolio/mitsui_2025/checkpoints/timesfm-1.0-200m/torch_model.ckpt
# 2025-10-02 15:28:22,268 - INFO - Sending checkpoint to device cpu
# 2025-10-02 15:28:24,139 - INFO - Loading checkpoint from /root/vscode/portfolio/mitsui_2025/checkpoints/timesfm-1.0-200m/torch_model.ckpt
# 2025-10-02 15:28:24,213 - INFO - Sending checkpoint to device cpu
# Initialized finetuner for target 0
# Initialized finetuner for target 1
# Initialized finetuner for target 2
# Initialized finetuner for target 3
# Initialized finetuner for target 4
# Initialized finetuner for target 5
# Initialized finetuner for target 6
# Initialized finetuner for target 7
# Initialized finetuner for target 8
# Initialized finetuner for target 9
# Initialized finetuner for target 10
# Initialized finetuner for target 11
# Initialized finetuner for target 12
# Initialized finetuner for target 13
# Initialized finetuner for target 14
# Initialized finetuner for target 15
# Initialized finetuner for target 16
# Initialized finetuner for target 17
# Initialized finetuner for target 18
# Initialized finetuner for target 19
# Initialized finetuner for target 20
# Initialized finetuner for target 21
# Initialized finetuner for target 22
# Initialized finetuner for target 23
# Initialized finetuner for target 24
# Initialized finetuner for target 25
# Initialized finetuner for target 26
# Initialized finetuner for target 27
# Initialized finetuner for target 28
# Initialized finetuner for target 29
# Initialized finetuner for target 30
# Initialized finetuner for target 31
# Initialized finetuner for target 32
# Initialized finetuner for target 33
# Initialized finetuner for target 34
# Initialized finetuner for target 35
# Initialized finetuner for target 36
# Initialized finetuner for target 37
# Initialized finetuner for target 38
# Initialized finetuner for target 39
# Initialized finetuner for target 40
# Initialized finetuner for target 41
# Initialized finetuner for target 42
# Initialized finetuner for target 43
# Initialized finetuner for target 44
# Initialized finetuner for target 45
# Initialized finetuner for target 46
# Initialized finetuner for target 47
# Initialized finetuner for target 48
# Initialized finetuner for target 49
# Initialized finetuner for target 50
# Initialized finetuner for target 51
# Initialized finetuner for target 52
# Initialized finetuner for target 53
# Initialized finetuner for target 54
# Initialized finetuner for target 55
# Initialized finetuner for target 56
# Initialized finetuner for target 57
# Initialized finetuner for target 58
# Initialized finetuner for target 59
# Initialized finetuner for target 60
# Initialized finetuner for target 61
# Initialized finetuner for target 62
# Initialized finetuner for target 63
# Initialized finetuner for target 64
# Initialized finetuner for target 65
# Initialized finetuner for target 66
# Initialized finetuner for target 67
# Initialized finetuner for target 68
# Initialized finetuner for target 69
# Initialized finetuner for target 70
# Initialized finetuner for target 71
# Initialized finetuner for target 72
# Initialized finetuner for target 73
# Initialized finetuner for target 74
# Initialized finetuner for target 75
# Initialized finetuner for target 76
# Initialized finetuner for target 77
# Initialized finetuner for target 78
# Initialized finetuner for target 79
# Initialized finetuner for target 80
# Initialized finetuner for target 81
# Initialized finetuner for target 82
# Initialized finetuner for target 83
# Initialized finetuner for target 84
# Initialized finetuner for target 85
# Initialized finetuner for target 86
# Initialized finetuner for target 87
# Initialized finetuner for target 88
# Initialized finetuner for target 89
# Initialized finetuner for target 90
# Initialized finetuner for target 91
# Initialized finetuner for target 92
# Initialized finetuner for target 93
# Initialized finetuner for target 94
# Initialized finetuner for target 95
# Initialized finetuner for target 96
# Initialized finetuner for target 97
# Initialized finetuner for target 98
# Initialized finetuner for target 99
# Initialized finetuner for target 100
# Initialized finetuner for target 101
# Initialized finetuner for target 102
# Initialized finetuner for target 103
# Initialized finetuner for target 104
# Initialized finetuner for target 105
# Initialized finetuner for target 106
# Initialized finetuner for target 107
# Initialized finetuner for target 108
# Initialized finetuner for target 109
# Initialized finetuner for target 110
# Initialized finetuner for target 111
# Initialized finetuner for target 112
# Initialized finetuner for target 113
# Initialized finetuner for target 114
# Initialized finetuner for target 115
# Initialized finetuner for target 116
# Initialized finetuner for target 117
# Initialized finetuner for target 118
# Initialized finetuner for target 119
# Initialized finetuner for target 120
# Initialized finetuner for target 121
# Initialized finetuner for target 122
# Initialized finetuner for target 123
# Initialized finetuner for target 124
# Initialized finetuner for target 125
# Initialized finetuner for target 126
# Initialized finetuner for target 127
# Initialized finetuner for target 128
# Initialized finetuner for target 129
# Initialized finetuner for target 130
# Initialized finetuner for target 131
# Initialized finetuner for target 132
# Initialized finetuner for target 133
# Initialized finetuner for target 134
# Initialized finetuner for target 135
# Initialized finetuner for target 136
# Initialized finetuner for target 137
# Initialized finetuner for target 138
# Initialized finetuner for target 139
# Initialized finetuner for target 140
# Initialized finetuner for target 141
# Initialized finetuner for target 142
# Initialized finetuner for target 143
# Initialized finetuner for target 144
# Initialized finetuner for target 145
# Initialized finetuner for target 146
# Initialized finetuner for target 147
# Initialized finetuner for target 148
# Initialized finetuner for target 149
# Initialized finetuner for target 150
# Initialized finetuner for target 151
# Initialized finetuner for target 152
# Initialized finetuner for target 153
# Initialized finetuner for target 154
# Initialized finetuner for target 155
# Initialized finetuner for target 156
# Initialized finetuner for target 157
# Initialized finetuner for target 158
# Initialized finetuner for target 159
# Initialized finetuner for target 160
# Initialized finetuner for target 161
# Initialized finetuner for target 162
# Initialized finetuner for target 163
# Initialized finetuner for target 164
# Initialized finetuner for target 165
# Initialized finetuner for target 166
# Initialized finetuner for target 167
# Initialized finetuner for target 168
# Initialized finetuner for target 169
# Initialized finetuner for target 170
# Initialized finetuner for target 171
# Initialized finetuner for target 172
# Initialized finetuner for target 173
# Initialized finetuner for target 174
# Initialized finetuner for target 175
# Initialized finetuner for target 176
# Initialized finetuner for target 177
# Initialized finetuner for target 178
# Initialized finetuner for target 179
# Initialized finetuner for target 180
# Initialized finetuner for target 181
# Initialized finetuner for target 182
# Initialized finetuner for target 183
# Initialized finetuner for target 184
# Initialized finetuner for target 185
# Initialized finetuner for target 186
# Initialized finetuner for target 187
# Initialized finetuner for target 188
# Initialized finetuner for target 189
# Initialized finetuner for target 190
# Initialized finetuner for target 191
# Initialized finetuner for target 192
# Initialized finetuner for target 193
# Initialized finetuner for target 194
# Initialized finetuner for target 195
# Initialized finetuner for target 196
# Initialized finetuner for target 197
# Initialized finetuner for target 198
# Initialized finetuner for target 199
# Initialized finetuner for target 200
# Initialized finetuner for target 201
# Initialized finetuner for target 202
# Initialized finetuner for target 203
# Initialized finetuner for target 204
# Initialized finetuner for target 205
# Initialized finetuner for target 206
# Initialized finetuner for target 207
# Initialized finetuner for target 208
# Initialized finetuner for target 209
# Initialized finetuner for target 210
# Initialized finetuner for target 211
# Initialized finetuner for target 212
# Initialized finetuner for target 213
# Initialized finetuner for target 214
# Initialized finetuner for target 215
# Initialized finetuner for target 216
# Initialized finetuner for target 217
# Initialized finetuner for target 218
# Initialized finetuner for target 219
# Initialized finetuner for target 220
# Initialized finetuner for target 221
# Initialized finetuner for target 222
# Initialized finetuner for target 223
# Initialized finetuner for target 224
# Initialized finetuner for target 225
# Initialized finetuner for target 226
# Initialized finetuner for target 227
# Initialized finetuner for target 228
# Initialized finetuner for target 229
# Initialized finetuner for target 230
# Initialized finetuner for target 231
# Initialized finetuner for target 232
# Initialized finetuner for target 233
# Initialized finetuner for target 234
# Initialized finetuner for target 235
# Initialized finetuner for target 236
# Initialized finetuner for target 237
# Initialized finetuner for target 238
# Initialized finetuner for target 239
# Initialized finetuner for target 240
# Initialized finetuner for target 241
# Initialized finetuner for target 242
# Initialized finetuner for target 243
# Initialized finetuner for target 244
# Initialized finetuner for target 245
# Initialized finetuner for target 246
# Initialized finetuner for target 247
# Initialized finetuner for target 248
# Initialized finetuner for target 249
# Initialized finetuner for target 250
# Initialized finetuner for target 251
# Initialized finetuner for target 252
# Initialized finetuner for target 253
# Initialized finetuner for target 254
# Initialized finetuner for target 255
# Initialized finetuner for target 256
# Initialized finetuner for target 257
# Initialized finetuner for target 258
# Initialized finetuner for target 259
# Initialized finetuner for target 260
# Initialized finetuner for target 261
# Initialized finetuner for target 262
# Initialized finetuner for target 263
# Initialized finetuner for target 264
# Initialized finetuner for target 265
# Initialized finetuner for target 266
# Initialized finetuner for target 267
# Initialized finetuner for target 268
# Initialized finetuner for target 269
# Initialized finetuner for target 270
# Initialized finetuner for target 271
# Initialized finetuner for target 272
# Initialized finetuner for target 273
# Initialized finetuner for target 274
# Initialized finetuner for target 275
# Initialized finetuner for target 276
# Initialized finetuner for target 277
# Initialized finetuner for target 278
# Initialized finetuner for target 279
# Initialized finetuner for target 280
# Initialized finetuner for target 281
# Initialized finetuner for target 282
# Initialized finetuner for target 283
# Initialized finetuner for target 284
# Initialized finetuner for target 285
# Initialized finetuner for target 286
# Initialized finetuner for target 287
# Initialized finetuner for target 288
# Initialized finetuner for target 289
# Initialized finetuner for target 290
# Initialized finetuner for target 291
# Initialized finetuner for target 292
# Initialized finetuner for target 293
# Initialized finetuner for target 294
# Initialized finetuner for target 295
# Initialized finetuner for target 296
# Initialized finetuner for target 297
# Initialized finetuner for target 298
# Initialized finetuner for target 299
# Initialized finetuner for target 300
# Initialized finetuner for target 301
# Initialized finetuner for target 302
# Initialized finetuner for target 303
# Initialized finetuner for target 304
# Initialized finetuner for target 305
# Initialized finetuner for target 306
# Initialized finetuner for target 307
# Initialized finetuner for target 308
# Initialized finetuner for target 309
# Initialized finetuner for target 310
# Initialized finetuner for target 311
# Initialized finetuner for target 312
# Initialized finetuner for target 313
# Initialized finetuner for target 314
# Initialized finetuner for target 315
# Initialized finetuner for target 316
# Initialized finetuner for target 317
# Initialized finetuner for target 318
# Initialized finetuner for target 319
# Initialized finetuner for target 320
# Initialized finetuner for target 321
# Initialized finetuner for target 322
# Initialized finetuner for target 323
# Initialized finetuner for target 324
# Initialized finetuner for target 325
# Initialized finetuner for target 326
# Initialized finetuner for target 327
# Initialized finetuner for target 328
# Initialized finetuner for target 329
# Initialized finetuner for target 330
# Initialized finetuner for target 331
# Initialized finetuner for target 332
# Initialized finetuner for target 333
# Initialized finetuner for target 334
# Initialized finetuner for target 335
# Initialized finetuner for target 336
# Initialized finetuner for target 337
# Initialized finetuner for target 338
# Initialized finetuner for target 339
# Initialized finetuner for target 340
# Initialized finetuner for target 341
# Initialized finetuner for target 342
# Initialized finetuner for target 343
# Initialized finetuner for target 344
# Initialized finetuner for target 345
# Initialized finetuner for target 346
# Initialized finetuner for target 347
# Initialized finetuner for target 348
# Initialized finetuner for target 349
# Initialized finetuner for target 350
# Initialized finetuner for target 351
# Initialized finetuner for target 352
# Initialized finetuner for target 353
# Initialized finetuner for target 354
# Initialized finetuner for target 355
# Initialized finetuner for target 356
# Initialized finetuner for target 357
# Initialized finetuner for target 358
# Initialized finetuner for target 359
# Initialized finetuner for target 360
# Initialized finetuner for target 361
# Initialized finetuner for target 362
# Initialized finetuner for target 363
# Initialized finetuner for target 364
# Initialized finetuner for target 365
# Initialized finetuner for target 366
# Initialized finetuner for target 367
# Initialized finetuner for target 368
# Initialized finetuner for target 369
# Initialized finetuner for target 370
# Initialized finetuner for target 371
# Initialized finetuner for target 372
# Initialized finetuner for target 373
# Initialized finetuner for target 374
# Initialized finetuner for target 375
# Initialized finetuner for target 376
# Initialized finetuner for target 377
# Initialized finetuner for target 378
# Initialized finetuner for target 379
# Initialized finetuner for target 380
# Initialized finetuner for target 381
# Initialized finetuner for target 382
# Initialized finetuner for target 383
# Initialized finetuner for target 384
# Initialized finetuner for target 385
# Initialized finetuner for target 386
# Initialized finetuner for target 387
# Initialized finetuner for target 388
# Initialized finetuner for target 389
# Initialized finetuner for target 390
# Initialized finetuner for target 391
# Initialized finetuner for target 392
# Initialized finetuner for target 393
# Initialized finetuner for target 394
# Initialized finetuner for target 395
# Initialized finetuner for target 396
# Initialized finetuner for target 397
# Initialized finetuner for target 398
# Initialized finetuner for target 399
# Initialized finetuner for target 400
# Initialized finetuner for target 401
# Initialized finetuner for target 402
# Initialized finetuner for target 403
# Initialized finetuner for target 404
# Initialized finetuner for target 405
# Initialized finetuner for target 406
# Initialized finetuner for target 407
# Initialized finetuner for target 408
# Initialized finetuner for target 409
# Initialized finetuner for target 410
# Initialized finetuner for target 411
# Initialized finetuner for target 412
# Initialized finetuner for target 413
# Initialized finetuner for target 414
# Initialized finetuner for target 415
# Initialized finetuner for target 416
# Initialized finetuner for target 417
# Initialized finetuner for target 418
# Initialized finetuner for target 419
# Initialized finetuner for target 420
# Initialized finetuner for target 421
# Initialized finetuner for target 422
# Initialized finetuner for target 423
# Model and finetuners initialized.

# %%
# Cell 6: Fine-Tuning Loop
# Fine-tune each of the 424 target series; save checkpoints and log metrics
# Ensure finetuning_torch.py is patched for _process_batch
import os
import torch


# Verify patch in finetuning_torch.py
from finetuning.finetuning_torch import TimesFMFinetuner
assert hasattr(TimesFMFinetuner, '_process_batch'), "Patch finetuning_torch.py with updated _process_batch"

# Fine-tune each target
histories = []
for i, (train_ds, val_ds) in enumerate(datasets):
    print(f"Fine-tuning target {i}/{len(datasets)-1}...")
    result = finetuners[i].finetune(train_dataset=train_ds, val_dataset=val_ds, single_step_pred=True)
    histories.append(result['history'])
    
    # Save checkpoint
    save_dir = f"../checkpoints/timesfm/finetuned_target_{i}"
    os.makedirs(save_dir, exist_ok=True)
    torch.save(finetuners[i].model.state_dict(), os.path.join(save_dir, "finetuned.pt"))
    
    # Log metrics to WandB
    if config.use_wandb:
        wandb.log({
            "target_id": i,
            "val_loss": min(result['history']['val_loss']),
            "train_loss": min(result['history']['train_loss']),
            "epoch": len(result['history']['val_loss'])
        })


print("Fine-tuning complete.")
print(f"Sample history for target 0: {histories[0]}")
# Out:
# Fine-tuning target 0/423...
# 2025-10-02 15:28:25,617 - INFO - Starting training for 50 epochs...
# 2025-10-02 15:28:25,618 - INFO - Training samples: 1021
# 2025-10-02 15:28:25,619 - INFO - Validation samples: 0
# 2025-10-02 15:28:25,862 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:26,229 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:26,507 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:26,796 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:27,070 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:27,373 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:27,679 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:27,987 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:28,288 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:28,594 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:28,900 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:29,199 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:29,504 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:29,806 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:30,116 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:30,425 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:30,733 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:31,043 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:31,357 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:31,661 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:31,952 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:32,250 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:32,528 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:32,832 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:33,138 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:33,442 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:33,741 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:34,040 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:34,341 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:34,642 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:34,915 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28:35,231 - INFO - last_patch_pred shape: torch.Size([29]), target shape: torch.Size([29])
# 2025-10-02 15:28:35,497 - WARNING - Validation loader has 0 batches; skipping validation this epoch.
# 2025-10-02 15:28:35,497 - INFO - [Epoch 1] Train Loss: 0.0922 | Val Loss: inf
# 2025-10-02 15:28:35,521 - INFO - last_patch_pred shape: torch.Size([32]), target shape: torch.Size([32])
# 2025-10-02 15:28