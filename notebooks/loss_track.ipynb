# %%
import pandas as pd 


d = '/root/vscode/portfolio/mitsui_2025/src/outputs/2025-10-01/05-34-25/study.log'

with open(d, 'r') as file:
    error_lines = [line for line in file if 'ERROR' in line]
    #print("Error lines:\n", '\n'.join(error_lines))
# Out:
# Error lines:
#  [2025-10-01 05:56:32,624][root][ERROR] - Trial 0 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# [2025-10-01 05:56:33,834][root][ERROR] - Trial 1 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# [2025-10-01 05:56:34,715][root][ERROR] - Trial 2 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# [2025-10-01 05:56:35,070][root][ERROR] - Trial 3 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# [2025-10-01 05:56:36,856][root][ERROR] - Trial 5 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# [2025-10-01 05:56:37,568][root][ERROR] - Trial 4 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# [2025-10-01 05:56:39,094][root][ERROR] - Trial 6 failed: CNNLSTMForecaster.__init__() got an unexpected keyword argument 'hidden_size'
#
# ...
